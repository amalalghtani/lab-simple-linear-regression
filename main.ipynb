#      -------------------                     6.0/11.7 MB 781.9 kB/s eta 0:00:08
#      --------------------                    6.1/11.7 MB 790.2 kB/s eta 0:00:08
#      --------------------                    6.2/11.7 MB 798.7 kB/s eta 0:00:07
#      ---------------------                   6.3/11.7 MB 811.0 kB/s eta 0:00:07
#      ---------------------                   6.5/11.7 MB 824.1 kB/s eta 0:00:07
#      ----------------------                  6.6/11.7 MB 838.7 kB/s eta 0:00:07
#      ----------------------                  6.8/11.7 MB 853.1 kB/s eta 0:00:06
#      -----------------------                 7.0/11.7 MB 874.7 kB/s eta 0:00:06
#      ------------------------                7.2/11.7 MB 897.6 kB/s eta 0:00:05
#      ------------------------                7.5/11.7 MB 921.1 kB/s eta 0:00:05
#      -------------------------               7.7/11.7 MB 948.5 kB/s eta 0:00:05
#      --------------------------              8.0/11.7 MB 971.2 kB/s eta 0:00:04
#      ---------------------------             8.1/11.7 MB 985.6 kB/s eta 0:00:04
#      ---------------------------             8.3/11.7 MB 999.7 kB/s eta 0:00:04
#      -----------------------------            8.7/11.7 MB 1.0 MB/s eta 0:00:03
#      ------------------------------           9.0/11.7 MB 1.1 MB/s eta 0:00:03
#      --------------------------------         9.4/11.7 MB 1.1 MB/s eta 0:00:03
#      ---------------------------------        9.9/11.7 MB 1.2 MB/s eta 0:00:02
#      -----------------------------------      10.5/11.7 MB 1.3 MB/s eta 0:00:01
#      -------------------------------------    11.1/11.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  11.7/11.7 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  11.7/11.7 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  11.7/11.7 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  11.7/11.7 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 11.7/11.7 MB 1.5 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib->datasist)
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
#                                               0.0/219.8 kB ? eta -:--:--
#      ------------------------------------  215.0/219.8 kB 13.7 MB/s eta 0:00:01
#      -------------------------------------- 219.8/219.8 kB 2.2 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib->datasist)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->datasist)
#   Downloading fonttools-4.56.0-cp311-cp311-win_amd64.whl (2.2 MB)
#                                               0.0/2.2 MB ? eta -:--:--
#      ------------                             0.7/2.2 MB 20.5 MB/s eta 0:00:01
#      ----------------------                   1.2/2.2 MB 12.9 MB/s eta 0:00:01
#      ----------------------------             1.5/2.2 MB 12.3 MB/s eta 0:00:01
#      -----------------------------------      2.0/2.2 MB 10.3 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 10.0 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 10.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 6.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->datasist)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#                                               0.0/72.0 kB ? eta -:--:--
#      ---------------------------------------  71.7/72.0 kB ? eta -:--:--
#      ---------------------------------------  71.7/72.0 kB ? eta -:--:--
#      ---------------------------------------  71.7/72.0 kB ? eta -:--:--
#      -------------------------------------- 72.0/72.0 kB 395.7 kB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\96655\appdata\roaming\python\python311\site-packages (from matplotlib->datasist) (24.2)
# Collecting pillow>=8 (from matplotlib->datasist)
#   Downloading pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#                                               0.0/2.6 MB ? eta -:--:--
#      ---------                                0.6/2.6 MB 20.5 MB/s eta 0:00:01
#      ---------------                          1.0/2.6 MB 16.0 MB/s eta 0:00:01
#      ----------------------                   1.5/2.6 MB 11.8 MB/s eta 0:00:01
#      ------------------------------           2.0/2.6 MB 10.6 MB/s eta 0:00:01
#      --------------------------------------   2.5/2.6 MB 11.4 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 MB 10.4 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 MB 10.4 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 7.3 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib->datasist)
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#                                               0.0/107.7 kB ? eta -:--:--
#      --------------------------------------   102.4/107.7 kB ? eta -:--:--
#      --------------------------------------   102.4/107.7 kB ? eta -:--:--
#      --------------------------------------   102.4/107.7 kB ? eta -:--:--
#      ------------------------------------ 107.7/107.7 kB 477.8 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\96655\appdata\roaming\python\python311\site-packages (from matplotlib->datasist) (2.9.0.post0)
# Collecting click (from nltk->datasist)
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#                                               0.0/98.2 kB ? eta -:--:--
#      -------------------------------------    92.2/98.2 kB ? eta -:--:--
#      ---------------------------------------- 98.2/98.2 kB 1.4 MB/s eta 0:00:00
# Collecting regex>=2021.8.3 (from nltk->datasist)
#   Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
#                                               0.0/274.1 kB ? eta -:--:--
#      --------------------------------------   266.2/274.1 kB ? eta -:--:--
#      -------------------------------------- 274.1/274.1 kB 3.4 MB/s eta 0:00:00
# Collecting tqdm (from nltk->datasist)
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#                                               0.0/78.5 kB ? eta -:--:--
#      ------------------------------------     71.7/78.5 kB ? eta -:--:--
#      ---------------------------------------- 78.5/78.5 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\96655\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasist) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\96655\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasist) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\96655\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->datasist) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\96655\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->datasist) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\96655\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->datasist) (1.17.0)
# Requirement already satisfied: colorama in c:\users\96655\appdata\roaming\python\python311\site-packages (from click->nltk->datasist) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (8.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (1.6.0)
# Requirement already satisfied: psutil in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->datasist) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->jupyter->datasist)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#                                               0.0/2.3 MB ? eta -:--:--
#      ---------                                0.6/2.3 MB 18.2 MB/s eta 0:00:01
#      ------------                             0.7/2.3 MB 7.4 MB/s eta 0:00:01
#      ---------------------                    1.3/2.3 MB 8.9 MB/s eta 0:00:01
#      -----------------------                  1.4/2.3 MB 8.8 MB/s eta 0:00:01
#      --------------------------               1.6/2.3 MB 7.6 MB/s eta 0:00:01
#      -----------------------------            1.7/2.3 MB 6.4 MB/s eta 0:00:01
#      ----------------------------------       2.0/2.3 MB 6.3 MB/s eta 0:00:01
#      ---------------------------------------  2.3/2.3 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------  2.3/2.3 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------  2.3/2.3 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.3/2.3 MB 4.5 MB/s eta 0:00:00
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->jupyter->datasist)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#                                               0.0/214.4 kB ? eta -:--:--
#      --------------------------------------   204.8/214.4 kB ? eta -:--:--
#      --------------------------------------   204.8/214.4 kB ? eta -:--:--
#      -------------------------------------- 214.4/214.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\96655\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter->datasist) (3.0.50)
# Requirement already satisfied: pygments in c:\users\96655\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter->datasist) (2.19.1)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->datasist)
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter->datasist)
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#                                               0.0/73.5 kB ? eta -:--:--
#      ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
# Collecting jinja2>=3.0.3 (from jupyterlab->jupyter->datasist)
#   Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#                                               0.0/134.6 kB ? eta -:--:--
#      -------------------------------------  133.1/134.6 kB 8.2 MB/s eta 0:00:01
#      -------------------------------------- 134.6/134.6 kB 2.0 MB/s eta 0:00:00
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->datasist)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#                                               0.0/69.1 kB ? eta -:--:--
#      ---------------------------------------- 69.1/69.1 kB 1.9 MB/s eta 0:00:00
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->datasist)
#   Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#                                               0.0/385.8 kB ? eta -:--:--
#      ------------------------------------  378.9/385.8 kB 23.0 MB/s eta 0:00:01
#      -------------------------------------- 385.8/385.8 kB 6.0 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->datasist)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#                                               0.0/59.7 kB ? eta -:--:--
#      ----------------------------------       51.2/59.7 kB ? eta -:--:--
#      ---------------------------------------- 59.7/59.7 kB 1.1 MB/s eta 0:00:00
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter->datasist)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\96655\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter->datasist) (65.5.0)
# Collecting beautifulsoup4 (from nbconvert->jupyter->datasist)
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
#                                               0.0/186.0 kB ? eta -:--:--
#                                               0.0/186.0 kB ? eta -:--:--
#                                               0.0/186.0 kB ? eta -:--:--
#      --                                       10.2/186.0 kB ? eta -:--:--
#      --                                       10.2/186.0 kB ? eta -:--:--
#      --                                       10.2/186.0 kB ? eta -:--:--
#      --                                       10.2/186.0 kB ? eta -:--:--
#      --                                       10.2/186.0 kB ? eta -:--:--
#      --                                       10.2/186.0 kB ? eta -:--:--
#      --                                       10.2/186.0 kB ? eta -:--:--
#      ------                                 30.7/186.0 kB 54.6 kB/s eta 0:00:03
#      ------                                 30.7/186.0 kB 54.6 kB/s eta 0:00:03
#      ------------                          61.4/186.0 kB 109.2 kB/s eta 0:00:02
#      ---------------------                112.6/186.0 kB 192.8 kB/s eta 0:00:01
#      -----------------------              122.9/186.0 kB 205.9 kB/s eta 0:00:01
#      ---------------------------          143.4/186.0 kB 218.6 kB/s eta 0:00:01
#      -----------------------------        153.6/186.0 kB 213.3 kB/s eta 0:00:01
#      -----------------------------        153.6/186.0 kB 213.3 kB/s eta 0:00:01
downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#                                               0.0/78.5 kB ? eta -:--:--
#      -----                                    10.2/78.5 kB ? eta -:--:--
#      ------------------------               51.2/78.5 kB 525.1 kB/s eta 0:00:01
#      ----------------------------------     71.7/78.5 kB 438.9 kB/s eta 0:00:01
#      -------------------------------------- 78.5/78.5 kB 437.3 kB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter->datasist)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting webencodings (from bleach[css]!=5.0.0->nbconvert->jupyter->datasist)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter->datasist)
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting anyio (from httpx>=0.25.0->jupyterlab->jupyter->datasist)
#   Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#                                               0.0/96.0 kB ? eta -:--:--
#      ------------                           30.7/96.0 kB 660.6 kB/s eta 0:00:01
#      ------------------------               61.4/96.0 kB 656.4 kB/s eta 0:00:01
#      ------------------------------------   92.2/96.0 kB 655.4 kB/s eta 0:00:01
#      -------------------------------------- 96.0/96.0 kB 612.9 kB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\users\96655\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->datasist) (2025.1.31)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter->datasist)
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#                                               0.0/78.6 kB ? eta -:--:--
#      ---------------                          30.7/78.6 kB 1.3 MB/s eta 0:00:01
#      ----------------------------------     71.7/78.6 kB 787.7 kB/s eta 0:00:01
#      -------------------------------------- 78.6/78.6 kB 484.5 kB/s eta 0:00:00
# Collecting idna (from httpx>=0.25.0->jupyterlab->jupyter->datasist)
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#                                               0.0/70.4 kB ? eta -:--:--
#      ----------------                       30.7/70.4 kB 660.6 kB/s eta 0:00:01
#      ----------------------------------       61.4/70.4 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 70.4/70.4 kB 640.4 kB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->datasist)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#                                               0.0/58.3 kB ? eta -:--:--
#      -------                                  10.2/58.3 kB ? eta -:--:--
#      --------------------                   30.7/58.3 kB 262.6 kB/s eta 0:00:01
#      ---------------------------------      51.2/58.3 kB 372.4 kB/s eta 0:00:01
#      -------------------------------------- 58.3/58.3 kB 307.8 kB/s eta 0:00:00
# Requirement already satisfied: decorator in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\96655\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (4.12.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\96655\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->datasist) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\96655\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->datasist) (308)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#                                               0.0/54.7 kB ? eta -:--:--
#      ----------------------------           41.0/54.7 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 54.7/54.7 kB 472.8 kB/s eta 0:00:00
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading pywinpty-2.0.15-cp311-cp311-win_amd64.whl (1.4 MB)
#                                               0.0/1.4 MB ? eta -:--:--
#      -                                        0.0/1.4 MB 991.0 kB/s eta 0:00:02
#      --                                       0.1/1.4 MB 1.2 MB/s eta 0:00:02
#      ----                                     0.1/1.4 MB 1.1 MB/s eta 0:00:02
#      -----                                    0.2/1.4 MB 1.1 MB/s eta 0:00:02
#      -------                                  0.3/1.4 MB 1.1 MB/s eta 0:00:02
#      ----------------                         4.1/10.2 MB 2.6 MB/s eta 0:00:03
#      ----------------                         4.2/10.2 MB 2.6 MB/s eta 0:00:03
#      -----------------                        4.5/10.2 MB 2.6 MB/s eta 0:00:03
#      ------------------                       4.6/10.2 MB 2.7 MB/s eta 0:00:03
#      ------------------                       4.8/10.2 MB 2.7 MB/s eta 0:00:03
#      -------------------                      5.0/10.2 MB 2.7 MB/s eta 0:00:02
#      --------------------                     5.2/10.2 MB 2.7 MB/s eta 0:00:02
#      --------------------                     5.3/10.2 MB 2.7 MB/s eta 0:00:02
#      ---------------------                    5.6/10.2 MB 2.8 MB/s eta 0:00:02
#      ----------------------                   5.7/10.2 MB 2.8 MB/s eta 0:00:02
#      -----------------------                  5.9/10.2 MB 2.8 MB/s eta 0:00:02
#      ------------------------                 6.2/10.2 MB 2.9 MB/s eta 0:00:02
#      -------------------------                6.4/10.2 MB 2.9 MB/s eta 0:00:02
#      --------------------------               6.6/10.2 MB 2.9 MB/s eta 0:00:02
#      ---------------------------              6.9/10.2 MB 3.0 MB/s eta 0:00:02
#      ----------------------------             7.1/10.2 MB 3.0 MB/s eta 0:00:02
#      ----------------------------             7.3/10.2 MB 3.0 MB/s eta 0:00:01
#      -----------------------------            7.5/10.2 MB 3.0 MB/s eta 0:00:01
#      ------------------------------           7.7/10.2 MB 3.0 MB/s eta 0:00:01
#      ------------------------------           7.9/10.2 MB 3.1 MB/s eta 0:00:01
#      -------------------------------          8.1/10.2 MB 3.1 MB/s eta 0:00:01
#      --------------------------------         8.2/10.2 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------        8.4/10.2 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------        8.6/10.2 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------       8.8/10.2 MB 3.1 MB/s eta 0:00:01
#      -----------------------------------      9.0/10.2 MB 3.2 MB/s eta 0:00:01
#      ------------------------------------     9.3/10.2 MB 3.2 MB/s eta 0:00:01
#      -------------------------------------    9.5/10.2 MB 3.2 MB/s eta 0:00:01
#      --------------------------------------   9.7/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  9.9/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.1/10.2 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.2/10.2 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------- 10.2/10.2 MB 2.9 MB/s eta 0:00:00
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#                                               0.0/88.5 kB ? eta -:--:--
#      ---------------------------------------- 88.5/88.5 kB 1.7 MB/s eta 0:00:00
# Collecting requests>=2.31 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#                                               0.0/64.9 kB ? eta -:--:--
#      ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter->datasist)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: wcwidth in c:\users\96655\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->datasist) (0.2.13)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter->datasist)
#   Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.0->jupyterlab->jupyter->datasist)
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\96655\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.8.4)
# Collecting attrs>=22.2.0 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
#                                               0.0/63.2 kB ? eta -:--:--
#      --------------------------------------   61.4/63.2 kB 3.2 MB/s eta 0:00:01
#      --------------------------------------   61.4/63.2 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 63.2/63.2 kB 562.9 kB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading rpds_py-0.23.1-cp311-cp311-win_amd64.whl (232 kB)
#                                               0.0/233.0 kB ? eta -:--:--
#      ------------------------------------   225.3/233.0 kB 6.9 MB/s eta 0:00:01
#      ------------------------------------   225.3/233.0 kB 6.9 MB/s eta 0:00:01
#      -------------------------------------- 233.0/233.0 kB 1.8 MB/s eta 0:00:00
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading python_json_logger-3.2.1-py3-none-any.whl (14 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
#                                               0.0/162.0 kB ? eta -:--:--
#      ------------------------------------   153.6/162.0 kB 9.6 MB/s eta 0:00:01
#      -------------------------------------- 162.0/162.0 kB 2.4 MB/s eta 0:00:00
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
#                                               0.0/102.4 kB ? eta -:--:--
#      -------------------------------------- 102.4/102.4 kB 2.0 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#                                               0.0/128.4 kB ? eta -:--:--
#      ------------------------------------   122.9/128.4 kB 7.0 MB/s eta 0:00:01
#      -------------------------------------- 128.4/128.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: executing>=1.2.0 in c:\users\96655\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->datasist) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\96655\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->datasist) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\96655\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.2.3)
# Collecting fqdn (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting uri-template (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=24.6.0 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
#                                               0.0/181.4 kB ? eta -:--:--
#                                               0.0/181.4 kB ? eta -:--:--
#      --                                       10.2/181.4 kB ? eta -:--:--
#      ------                                30.7/181.4 kB 262.6 kB/s eta 0:00:01
#      --------                              41.0/181.4 kB 281.8 kB/s eta 0:00:01
#      ------------                          61.4/181.4 kB 328.2 kB/s eta 0:00:01
#      ------------------                    92.2/181.4 kB 350.1 kB/s eta 0:00:01
#      ------------------------             122.9/181.4 kB 379.3 kB/s eta 0:00:01
#      ----------------------------         143.4/181.4 kB 388.1 kB/s eta 0:00:01
#      ----------------------------------   174.1/181.4 kB 420.1 kB/s eta 0:00:01
#      ----------------------------------   174.1/181.4 kB 420.1 kB/s eta 0:00:01
#      ------------------------------------ 181.4/181.4 kB 353.6 kB/s eta 0:00:00
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->datasist)
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#                                               0.0/117.6 kB ? eta -:--:--
#      ---------                             30.7/117.6 kB 640.0 kB/s eta 0:00:01
#      -------------------                   61.4/117.6 kB 656.4 kB/s eta 0:00:01
#      -----------------------------         92.2/117.6 kB 655.4 kB/s eta 0:00:01
#      ----------------------------------   112.6/117.6 kB 652.2 kB/s eta 0:00:01
#      ------------------------------------ 117.6/117.6 kB 490.0 kB/s eta 0:00:00
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#                                               0.0/66.4 kB ? eta -:--:--
#      -----------------                      30.7/66.4 kB 660.6 kB/s eta 0:00:01
#      -----------------------------------    61.4/66.4 kB 656.4 kB/s eta 0:00:01
#      -------------------------------------- 66.4/66.4 kB 449.4 kB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->datasist)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, fastjsonschema, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, types-python-dateutil, tqdm, tinycss2, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, regex, pyyaml, pywinpty, python-json-logger, pyparsing, pycparser, prometheus-client, pillow, pandocfilters, overrides, mistune, markupsafe, kiwisolver, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, idna, h11, fqdn, fonttools, defusedxml, cycler, contourpy, click, charset-normalizer, bleach, babel, attrs, async-lru, terminado, requests, referencing, nltk, matplotlib, jinja2, httpcore, cffi, beautifulsoup4, arrow, anyio, seaborn, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, httpx, argon2-cffi-bindings, jupyter-console, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, datasist
# Successfully installed anyio-4.8.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-25.1.0 babel-2.17.0 beautifulsoup4-4.13.3 bleach-6.2.0 cffi-1.17.1 charset-normalizer-3.4.1 click-8.1.8 contourpy-1.3.1 cycler-0.12.1 datasist-1.5.3 defusedxml-0.7.1 fastjsonschema-2.21.1 fonttools-4.56.0 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 ipywidgets-8.1.5 isoduration-20.11.0 jinja2-3.1.5 json5-0.10.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 kiwisolver-1.4.8 markupsafe-3.0.2 matplotlib-3.10.0 mistune-3.1.2 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 nltk-3.9.1 notebook-7.3.2 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 pillow-11.1.0 prometheus-client-0.21.1 pycparser-2.22 pyparsing-3.2.1 python-json-logger-3.2.1 pywinpty-2.0.15 pyyaml-6.0.2 referencing-0.36.2 regex-2024.11.6 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.23.1 seaborn-0.13.2 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 terminado-0.18.1 tinycss2-1.4.0 tqdm-4.67.1 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 urllib3-2.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.13
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Downloading Data
# To download the data, we will use !wget to download it from IBM Object Storage.

# %%
#!wget -O FuelConsumption.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/FuelConsumptionCo2.csv
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# In case you're working **locally** uncomment the below line.

# %%
#!curl https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/FuelConsumptionCo2.csv -o FuelConsumptionCo2.csv
# Out:
# 'curl' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Understanding the Data
#
# ### `FuelConsumption.csv`:
# We have downloaded a fuel consumption dataset, **`FuelConsumption.csv`**, which contains model-specific fuel consumption ratings and estimated carbon dioxide emissions for new light-duty vehicles for retail sale in Canada. [Dataset source](http://open.canada.ca/data/en/dataset/98f1a129-f628-4ce4-b24d-6f16bf24dd64)
#
# - **MODELYEAR** e.g. 2014
# - **MAKE** e.g. Acura
# - **MODEL** e.g. ILX
# - **VEHICLE CLASS** e.g. SUV
# - **ENGINE SIZE** e.g. 4.7
# - **CYLINDERS** e.g 6
# - **TRANSMISSION** e.g. A6
# - **FUEL CONSUMPTION in CITY(L/100 km)** e.g. 9.9
# - **FUEL CONSUMPTION in HWY (L/100 km)** e.g. 8.9
# - **FUEL CONSUMPTION COMB (L/100 km)** e.g. 9.2
# - **CO2 EMISSIONS (g/km)** e.g. 182   --> low --> 0

# %% [markdown]
# ## Reading the data in

# %%
df = pd.read_csv("FuelConsumptionCo2.csv")

# take a look at the dataset
print(df.head())
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %% [markdown]
# ### Data Exploration
# Let's first have a descriptive exploration on our data.

# %%
# summarize the data
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %% [markdown]
# Let's select some features to explore more.

# %%
cdf = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %% [markdown]
# We can plot each of these features:

# %%
viz = cdf[['CYLINDERS','ENGINESIZE','CO2EMISSIONS','FUELCONSUMPTION_COMB']]
viz.hist()
plt.show()

# %% [markdown]
# Now, let's plot each of these features against the Emission, to see how linear their relationship is:

# %%
plt.scatter(cdf.FUELCONSUMPTION_COMB, cdf.CO2EMISSIONS,  color='blue')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(cdf.ENGINESIZE, cdf.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# ## Practice
# Plot __CYLINDER__ vs the Emission, to see how linear is their relationship is:

# %%
# write your code here
plt.scatter(cdf.CYLINDERS, cdf.CO2EMISSIONS,  color='blue')
plt.xlabel("CYLINDERS")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# plt.scatter(cdf.CYLINDERS, cdf.CO2EMISSIONS, color='blue')
# plt.xlabel("Cylinders")
# plt.ylabel("Emission")
# plt.show()
#
# ```
#
# </details>

# %% [markdown]
# #### Creating train and test dataset
# Train/Test Split involves splitting the dataset into training and testing sets that are mutually exclusive. After which, you train with the training set and test with the testing set.
# This will provide a more accurate evaluation on out-of-sample accuracy because the testing dataset is not part of the dataset that have been used to train the model. Therefore, it gives us a better understanding of how well our model generalizes on new data.
#
# This means that we know the outcome of each data point in the testing dataset, making it great to test with! Since this data has not been used to train the model, the model has no knowledge of the outcome of these data points. So, in essence, it is truly an out-of-sample testing.
#
# Let's split our dataset into train and test sets. 80% of the entire dataset will be used for training and 20% for testing. We create a mask to select random rows using __np.random.rand()__ function:

# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %% [markdown]
# ### Simple Regression Model
# Linear Regression fits a linear model with coefficients B = (B1, ..., Bn) to minimize the 'residual sum of squares' between the actual value y in the dataset, and the predicted value yhat using linear approximation.

# %% [markdown]
# #### Train data distribution

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# #### Modeling
# Using sklearn package to model data.

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[39.19984304]]
# Intercept:  [124.55583621]

# %% [markdown]
# As mentioned before, __Coefficient__ and __Intercept__ in the simple linear regression, are the parameters of the fit line.
# Given that it is a simple linear regression, with only 2 parameters, and knowing that the parameters are the intercept and slope of the line, sklearn can estimate them directly from our data.
# Notice that all of the data must be available to traverse and calculate the parameters.

# %% [markdown]
# #### Plot outputs

# %% [markdown]
# We can plot the fit line over the data:

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %% [markdown]
# #### Evaluation
# We compare the actual values and predicted values to calculate the accuracy of a regression model. Evaluation metrics provide a key role in the development of a model, as it provides insight to areas that require improvement.
#
# There are different model evaluation metrics, lets use MSE here to calculate the accuracy of our model based on the test set:
# * Mean Absolute Error: It is the mean of the absolute value of the errors. This is the easiest of the metrics to understand since it’s just average error.
#
# * Mean Squared Error (MSE): Mean Squared Error (MSE) is the mean of the squared error. It’s more popular than Mean Absolute Error because the focus is geared more towards large errors. This is due to the squared term exponentially increasing larger errors in comparison to smaller ones.
#
# * Root Mean Squared Error (RMSE).
#
# * R-squared is not an error, but rather a popular metric to measure the performance of your regression model. It represents how close the data points are to the fitted regression line. The higher the R-squared value, the better the model fits your data. The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['ENGINESIZE']])
test_y = np.asanyarray(test[['CO2EMISSIONS']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 24.68
# Residual sum of squares (MSE): 1078.03
# R2-score: 0.75

# %% [markdown]
# ## Exercise

# %% [markdown]
# Lets see what the evaluation metrics are if we trained a regression model using the `FUELCONSUMPTION_COMB` feature.
#
# Start by selecting `FUELCONSUMPTION_COMB` as the train_x data from the `train` dataframe, then select `FUELCONSUMPTION_COMB` as the test_x data from the `test` dataframe

# %%
train_x = train[["FUELCONSUMPTION_COMB"]]

test_x = test[["FUELCONSUMPTION_COMB"]]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# train_x = train[["FUELCONSUMPTION_COMB"]]
#
# test_x = test[["FUELCONSUMPTION_COMB"]]
#
# ```
#
# </details>

# %% [markdown]
# Now train a Linear Regression Model using the `train_x` you created and the `train_y` created previously

# %%
regr = linear_model.LinearRegression()

#ADD CODE

regr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# regr = linear_model.LinearRegression()
#
# regr.fit(train_x, train_y)
#
# ```
#
# </details>

# %% [markdown]
# Find the predictions using the model's `predict` function and the `test_x` data

# %%
#ADD CODE
predictions = regr.predict(test_x)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# predictions = regr.predict(test_x)
#
# ```
#
# </details>

# %% [markdown]
# Finally use the `predictions` and the `test_y` data and find the Mean Absolute Error value using the `np.absolute` and `np.mean` function like done previously

# %%
#ADD CODE
print("Mean Absolute Error: %.2f" % np.mean(np.absolute(predictions - test_y)))
# Out:
# Mean Absolute Error: 20.81

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# print("Mean Absolute Error: %.2f" % np.mean(np.absolute(predictions - test_y)))
#
# ```
#
# </details>

# %% [markdown]
# We can see that the MAE is much worse when we train using `ENGINESIZE` than `FUELCONSUMPTION_COMB`

# %% [markdown]
# ### Repeat everything you did using two additional regression models [optional]

# %% [markdown]
# ### Thank you for completing the lab!
